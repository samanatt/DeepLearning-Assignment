# %% [markdown]
# <center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">به نام خدا</div></center>
#
# <h1><center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">تمرین عملی 1: طبقه بندی با شبکه های تمام متصل روی مجموعه داده IRIS</div></center></h1>

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">صورت مساله</div>
#
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# در اولین جلسه کارگاه طبقه بندی با شبکه های تمام متصل را دیدیم.
# <br>
# توصیه می‌شود حتما نوت بوک‌های زیر را قبل از این تمرین مرور کنید:
# </div>
#
# [04_a Gentle Introduction to Keras - Simple neural network(mlp).ipynb](https://nbviewer.jupyter.org/github/alireza-akhavan/SRU-deeplearning-workshop/blob/master/04_a%20Gentle%20Introduction%20to%20Keras%20-%20Simple%20neural%20network%28mlp%29.ipynb)
#
# [05_Dropout.ipynb](https://nbviewer.jupyter.org/github/alireza-akhavan/SRU-deeplearning-workshop/blob/master/05_Dropout.ipynb)
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# در این جلسه با داده های تصویری آشنا شدیم. اما در این تمرین برای اینکه بدانیم کاربرد این مباحث در مسائل غیر تصویری نیز هست  از مجموعه داده ی ساختار یافتهiris  شامل 4 ویژگی برای طول و عرض کاسبرگ و گلبرگ استفاده خواهیم کرد که بتوانیم بر اساس این ویژگی ها نوع گل را از 3 کلاس متفاوت تشخیص دهیم.
# </div>

# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">لود کتابخانه های مورد نیاز </div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# کتابخانه های مورد نیاز این تمرین لود شده اند
# <br>
# در صورت نیاز میتوانید کتابخانه های بیشتری لود کنید:
# </div>

# %%
import numpy as np
from tensorflow import keras
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# در این تمرین میخواهیم از مجموعه داده iris استفاده کنیم.
# <br>
# توضیحات این مجموعه داده در سایت آن موجود است:
# </div>
#
# https://archive.ics.uci.edu/ml/datasets/iris
#
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# ویژگی ها و کلاس های این مجموعه داده به شرح زیر است:
# </div>
#
# Attribute Information:
#
# 1. sepal length in cm
# 2. sepal width in cm
# 3. petal length in cm
# 4. petal width in cm
#
# class:
#
#     Iris Setosa
#     Iris Versicolour
#     Iris Virginica
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# این دیتاست در کتابخانه sklearn موجود است
# <br>
# در قطعه کد زیر ویژگی ها را در x و برچسب یا labelهای متناظر را در y لود شده است.
# </div>

# %%
iris_data = load_iris() # load the iris dataset
x = iris_data.data
y = iris_data.target.reshape(-1, 1) # Convert data to a single column

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">سوال 1:</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# برچسب یا label های ما در حال حاضر عددی است.
# <br>
# این اعداد 0 تا 2 هستند و به عبارتی 3 حالت مختلف دارند.
# <br>
# این برچسب ها را به فرمت one-hot تبدیل کنید و خروجی را مجدد در y بریزید.
#
# <br>
# <b>راهنمایی: </b>
# از تابع keras.utils.to_categorical استفاده کنید.
# </div>

# %%
y = keras.utils.to_categorical(num_classes=3,y=y)

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# در زیر داده ها  به داده های test و train تقسیم شده است:
# </div>

# %%
# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">سوال 2:</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# یک شبکه با دو hidden-layer در هر لایه 10 نوران و تابع فعالیت relu بسازید. یک لایه Dropout با نرخ 0.5 در لایه آخر ماقبل softmax نیز اضافه کنید.
# </div>

# %%
# Build the model
from keras import layers
from keras import models
model =Sequential()
model.add(Dense(10,activation='relu',input_dim =4))
model.add(Dense(10,activation='relu'))
model.add(Dense(3,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 10)                50
#
#  dense_7 (Dense)             (None, 10)                110
#
#  dense_8 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 193 (772.00 Byte)
# Trainable params: 193 (772.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">در زیر مدل کامپایل شده است.</div>

# %%
# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">سوال 3:</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# مدل را با  batch_size=5 و تعداد 200 ایپاک آموزش دهید.
# <br>
# <b>راهنمایی: </b>
# از تابع model.fit استفاده کنید.
# </div>

# %%
history = model.fit(
    train_x, train_y,
    epochs = 200,
    batch_size= 5
)
# Out:
# Epoch 1/200
# 24/24 [==============================] - 3s 3ms/step - loss: 2.2762 - accuracy: 0.3500
# Epoch 2/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4088 - accuracy: 0.3500
# Epoch 3/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9348 - accuracy: 0.3500
# Epoch 4/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7511 - accuracy: 0.5167
# Epoch 5/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6774 - accuracy: 0.6667
# Epoch 6/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6447 - accuracy: 0.7250
# Epoch 7/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6203 - accuracy: 0.7500
# Epoch 8/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6001 - accuracy: 0.8583
# Epoch 9/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5798 - accuracy: 0.8750
# Epoch 10/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5609 - accuracy: 0.9000
# Epoch 11/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5415 - accuracy: 0.9417
# Epoch 12/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5288 - accuracy: 0.8917
# Epoch 13/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5140 - accuracy: 0.9583
# Epoch 14/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4979 - accuracy: 0.9333
# Epoch 15/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4806 - accuracy: 0.9250
# Epoch 16/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4667 - accuracy: 0.9500
# Epoch 17/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4494 - accuracy: 0.9333
# Epoch 18/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.9500
# Epoch 19/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4241 - accuracy: 0.9750
# Epoch 20/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4089 - accuracy: 0.9250
# Epoch 21/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3960 - accuracy: 0.9667
# Epoch 22/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3795 - accuracy: 0.9500
# Epoch 23/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3610 - accuracy: 0.9500
# Epoch 24/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3443 - accuracy: 0.9667
# Epoch 25/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.9500
# Epoch 26/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3101 - accuracy: 0.9667
# Epoch 27/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2956 - accuracy: 0.9667
# Epoch 28/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.9583
# Epoch 29/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2753 - accuracy: 0.9667
# Epoch 30/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2512 - accuracy: 0.9583
# Epoch 31/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2400 - accuracy: 0.9667
# Epoch 32/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2239 - accuracy: 0.9583
# Epoch 33/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2109 - accuracy: 0.9500
# Epoch 34/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2080 - accuracy: 0.9583
# Epoch 35/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1943 - accuracy: 0.9500
# Epoch 36/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1815 - accuracy: 0.9750
# Epoch 37/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1792 - accuracy: 0.9500
# Epoch 38/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1680 - accuracy: 0.9750
# Epoch 39/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1586 - accuracy: 0.9750
# Epoch 40/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1513 - accuracy: 0.9750
# Epoch 41/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9750
# Epoch 42/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1402 - accuracy: 0.9667
# Epoch 43/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1350 - accuracy: 0.9750
# Epoch 44/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1301 - accuracy: 0.9667
# Epoch 45/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1286 - accuracy: 0.9750
# Epoch 46/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1291 - accuracy: 0.9750
# Epoch 47/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1227 - accuracy: 0.9583
# Epoch 48/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1214 - accuracy: 0.9750
# Epoch 49/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1270 - accuracy: 0.9583
# Epoch 50/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1177 - accuracy: 0.9750
# Epoch 51/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1150 - accuracy: 0.9583
# Epoch 52/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1143 - accuracy: 0.9667
# Epoch 53/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1187 - accuracy: 0.9667
# Epoch 54/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.9583
# Epoch 55/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.9667
# Epoch 56/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1092 - accuracy: 0.9667
# Epoch 57/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1073 - accuracy: 0.9750
# Epoch 58/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9667
# Epoch 59/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1077 - accuracy: 0.9667
# Epoch 60/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1060 - accuracy: 0.9500
# Epoch 61/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1039 - accuracy: 0.9750
# Epoch 62/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1060 - accuracy: 0.9667
# Epoch 63/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1004 - accuracy: 0.9667
# Epoch 64/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1017 - accuracy: 0.9750
# Epoch 65/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.9583
# Epoch 66/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1128 - accuracy: 0.9583
# Epoch 67/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1001 - accuracy: 0.9667
# Epoch 68/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0969 - accuracy: 0.9750
# Epoch 69/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.9583
# Epoch 70/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1120 - accuracy: 0.9583
# Epoch 71/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0998 - accuracy: 0.9750
# Epoch 72/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1065 - accuracy: 0.9583
# Epoch 73/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0948 - accuracy: 0.9583
# Epoch 74/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9750
# Epoch 75/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9750
# Epoch 76/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0934 - accuracy: 0.9750
# Epoch 77/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0936 - accuracy: 0.9750
# Epoch 78/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.9750
# Epoch 79/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0933 - accuracy: 0.9750
# Epoch 80/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1011 - accuracy: 0.9667
# Epoch 81/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9750
# Epoch 82/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0921 - accuracy: 0.9583
# Epoch 83/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 0.9750
# Epoch 84/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 0.9750
# Epoch 85/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0917 - accuracy: 0.9750
# Epoch 86/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0959 - accuracy: 0.9667
# Epoch 87/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0846 - accuracy: 0.9750
# Epoch 88/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.9750
# Epoch 89/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0858 - accuracy: 0.9750
# Epoch 90/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0945 - accuracy: 0.9667
# Epoch 91/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1065 - accuracy: 0.9667
# Epoch 92/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0881 - accuracy: 0.9667
# Epoch 93/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0846 - accuracy: 0.9750
# Epoch 94/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0842 - accuracy: 0.9667
# Epoch 95/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0844 - accuracy: 0.9583
# Epoch 96/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0869 - accuracy: 0.9667
# Epoch 97/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0896 - accuracy: 0.9667
# Epoch 98/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0835 - accuracy: 0.9750
# Epoch 99/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0899 - accuracy: 0.9750
# Epoch 100/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.9583
# Epoch 101/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1005 - accuracy: 0.9583
# Epoch 102/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.9667
# Epoch 103/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0807 - accuracy: 0.9833
# Epoch 104/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0892 - accuracy: 0.9667
# Epoch 105/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0806 - accuracy: 0.9750
# Epoch 106/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0947 - accuracy: 0.9667
# Epoch 107/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0851 - accuracy: 0.9667
# Epoch 108/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.9750
# Epoch 109/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9750
# Epoch 110/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0777 - accuracy: 0.9833
# Epoch 111/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0797 - accuracy: 0.9667
# Epoch 112/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.9667
# Epoch 113/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9667
# Epoch 114/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9667
# Epoch 115/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0763 - accuracy: 0.9750
# Epoch 116/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 0.9833
# Epoch 117/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0922 - accuracy: 0.9500
# Epoch 118/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9750
# Epoch 119/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0798 - accuracy: 0.9667
# Epoch 120/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 0.9917
# Epoch 121/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0748 - accuracy: 0.9750
# Epoch 122/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0763 - accuracy: 0.9750
# Epoch 123/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9750
# Epoch 124/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0853 - accuracy: 0.9750
# Epoch 125/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0717 - accuracy: 0.9750
# Epoch 126/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0825 - accuracy: 0.9667
# Epoch 127/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9667
# Epoch 128/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0800 - accuracy: 0.9833
# Epoch 129/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0739 - accuracy: 0.9833
# Epoch 130/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0803 - accuracy: 0.9667
# Epoch 131/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.9750
# Epoch 132/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9750
# Epoch 133/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0733 - accuracy: 0.9750
# Epoch 134/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0787 - accuracy: 0.9583
# Epoch 135/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0757 - accuracy: 0.9583
# Epoch 136/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0707 - accuracy: 0.9833
# Epoch 137/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0725 - accuracy: 0.9750
# Epoch 138/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0688 - accuracy: 0.9750
# Epoch 139/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0725 - accuracy: 0.9833
# Epoch 140/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0691 - accuracy: 0.9833
# Epoch 141/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0712 - accuracy: 0.9833
# Epoch 142/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 0.9667
# Epoch 143/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0877 - accuracy: 0.9667
# Epoch 144/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9667
# Epoch 145/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9667
# Epoch 146/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9833
# Epoch 147/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0715 - accuracy: 0.9833
# Epoch 148/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0721 - accuracy: 0.9833
# Epoch 149/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0756 - accuracy: 0.9750
# Epoch 150/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9750
# Epoch 151/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9833
# Epoch 152/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0657 - accuracy: 0.9833
# Epoch 153/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0673 - accuracy: 0.9833
# Epoch 154/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0678 - accuracy: 0.9750
# Epoch 155/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 0.9833
# Epoch 156/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9833
# Epoch 157/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0692 - accuracy: 0.9750
# Epoch 158/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0709 - accuracy: 0.9833
# Epoch 159/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0698 - accuracy: 0.9750
# Epoch 160/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0701 - accuracy: 0.9750
# Epoch 161/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0696 - accuracy: 0.9750
# Epoch 162/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0721 - accuracy: 0.9833
# Epoch 163/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9917
# Epoch 164/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9833
# Epoch 165/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0687 - accuracy: 0.9917
# Epoch 166/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0677 - accuracy: 0.9750
# Epoch 167/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0683 - accuracy: 0.9750
# Epoch 168/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0847 - accuracy: 0.9667
# Epoch 169/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0683 - accuracy: 0.9667
# Epoch 170/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0693 - accuracy: 0.9750
# Epoch 171/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0692 - accuracy: 0.9833
# Epoch 172/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0663 - accuracy: 0.9750
# Epoch 173/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0659 - accuracy: 0.9833
# Epoch 174/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0655 - accuracy: 0.9833
# Epoch 175/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0674 - accuracy: 0.9667
# Epoch 176/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9833
# Epoch 177/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0635 - accuracy: 0.9833
# Epoch 178/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0689 - accuracy: 0.9833
# Epoch 179/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9833
# Epoch 180/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9750
# Epoch 181/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 0.9833
# Epoch 182/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9750
# Epoch 183/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0676 - accuracy: 0.9833
# Epoch 184/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9667
# Epoch 185/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0691 - accuracy: 0.9750
# Epoch 186/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0724 - accuracy: 0.9583
# Epoch 187/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9750
# Epoch 188/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 0.9750
# Epoch 189/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9833
# Epoch 190/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0617 - accuracy: 0.9833
# Epoch 191/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9750
# Epoch 192/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0616 - accuracy: 0.9833
# Epoch 193/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0701 - accuracy: 0.9750
# Epoch 194/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0628 - accuracy: 0.9750
# Epoch 195/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0736 - accuracy: 0.9750
# Epoch 196/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9750
# Epoch 197/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 0.9750
# Epoch 198/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0634 - accuracy: 0.9750
# Epoch 199/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0671 - accuracy: 0.9750
# Epoch 200/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0677 - accuracy: 0.9750

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">سوال 4:</div>
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# مدل را روی داده های test ارزیابی کنید.
# <br>
# <b>راهنمایی: </b>
# از تابع model.evaluate استفاده کنید.
# </div>

# %%
# Test on unseen data
results = model.evaluate(test_x, test_y)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0202 - accuracy: 1.0000
# Final test set loss: 0.020207
# Final test set accuracy: 1.000000
